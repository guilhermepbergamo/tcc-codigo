# %% [markdown]
# ## Etapas do projeto:
# 1. Definição do Problema de Negócio e Objetivo do projeto
# 2. Coleta e preparação dos dados
# 3. Análise Exploratória de Dados
# 4. Pré-processamento de Dados
# 5. Modelagem e Avaliação do Modelo
# 6. Interpretação dos Resultados
# 7. Deploy do Modelo
# 8. Aplicação do Modelo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import openpyxl
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

# %%
#Carregando os dados e transformando o arquivo xlsx em um dataframe do pandas
dataset = pd.read_excel('C:/Users/guipi/Desktop/tcc codigo/DADOSTCC.xlsx', sheet_name='Sheet1', engine='openpyxl')
dataset.head()
# Out:
#                                       Track Name    Artist Name  \
# 0                                Blinding Lights     The Weeknd
# 1                                   Shape of You     Ed Sheeran
# 2                              Someone You Loved  Lewis Capaldi
# 3  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 4                                        Starboy     The Weeknd
#
#                                           Album Name Release Date  Popularity  \
# 0                               After Hours (Deluxe)   2020-04-03          49
# 1                                         ÷ (Deluxe)   2017-03-03          88
# 2  Divinely Uninspired To A Hellish Extent (Exten...   2019-11-22          50
# 3                               Hollywood's Bleeding   2019-09-06          86
# 4                                            Starboy   2016-11-25          93
#
#    Duration (ms)  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0         200046         0.518   0.727    1    -5.947     1       0.0557
# 1         233713         0.825   0.652    1    -3.183     0       0.0802
# 2         182173         0.501   0.405    1    -5.679     1       0.0319
# 3         157560         0.755   0.522    2    -4.368     1       0.0575
# 4         230453         0.679   0.587    7    -7.015     1       0.2760
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo     Streams
# 0       0.00153          0.000152    0.0882    0.342  170.962  4114814660
# 1       0.58100          0.000000    0.0931    0.931   95.977  3810796529
# 2       0.75100          0.000000    0.1050    0.446  109.891  3261687586
# 3       0.53300          0.000000    0.0685    0.925   89.960  3201899849
# 4       0.14100          0.000006    0.1370    0.486  186.003  3096941898

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1943 entries, 0 to 1942
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Name        1943 non-null   object
#  1   Artist Name       1943 non-null   object
#  2   Album Name        1943 non-null   object
#  3   Release Date      1943 non-null   datetime64[ns]
#  4   Popularity        1943 non-null   int64
#  5   Duration (ms)     1943 non-null   int64
#  6   Danceability      1943 non-null   float64
#  7   Energy            1943 non-null   float64
#  8   Key               1943 non-null   int64
#  9   Loudness          1943 non-null   float64
#  10  Mode              1943 non-null   int64
#  11  Speechiness       1943 non-null   float64
#  12  Acousticness      1943 non-null   float64
#  13  Instrumentalness  1943 non-null   float64
#  14  Liveness          1943 non-null   float64
#  15  Valence           1943 non-null   float64
#  16  Tempo             1943 non-null   float64
#  17  Streams           1943 non-null   int64
# dtypes: datetime64[ns](1), float64(9), int64(5), object(3)
# memory usage: 273.4+ KB

# %%
dataset['Release Date'] = pd.to_datetime(dataset['Release Date'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1943 entries, 0 to 1942
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track Name        1943 non-null   object
#  1   Artist Name       1943 non-null   object
#  2   Album Name        1943 non-null   object
#  3   Release Date      1943 non-null   datetime64[ns]
#  4   Popularity        1943 non-null   int64
#  5   Duration (ms)     1943 non-null   int64
#  6   Danceability      1943 non-null   float64
#  7   Energy            1943 non-null   float64
#  8   Key               1943 non-null   int64
#  9   Loudness          1943 non-null   float64
#  10  Mode              1943 non-null   int64
#  11  Speechiness       1943 non-null   float64
#  12  Acousticness      1943 non-null   float64
#  13  Instrumentalness  1943 non-null   float64
#  14  Liveness          1943 non-null   float64
#  15  Valence           1943 non-null   float64
#  16  Tempo             1943 non-null   float64
#  17  Streams           1943 non-null   int64
# dtypes: datetime64[ns](1), float64(9), int64(5), object(3)
# memory usage: 273.4+ KB

# %%
dataset.shape
# Out:
# (1943, 18)

# %%
#Verificando se há valores nulos ou faltantes nos dados
missing = dataset.isnull().sum()
missing
# Out:
# Track Name          0
# Artist Name         0
# Album Name          0
# Release Date        0
# Popularity          0
# Duration (ms)       0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Streams             0
# dtype: int64

# %% [markdown]
# ### 3.Análise Exploratória e Visualização dos dados

# %%
dataset.describe()
# Out:
#         Popularity  Duration (ms)  Danceability       Energy          Key  \
# count  1943.000000    1943.000000   1943.000000  1943.000000  1943.000000
# mean     71.625322  219983.194030      0.651233     0.652604     5.240350
# std      19.684029   50345.944181      0.148393     0.177660     3.636606
# min       0.000000   80927.000000      0.000000     0.000020     0.000000
# 25%      71.000000  190464.500000      0.558000     0.538000     2.000000
# 50%      78.000000  214827.000000      0.666000     0.672000     5.000000
# 75%      82.000000  241740.000000      0.760000     0.784500     8.000000
# max      98.000000  613027.000000      0.967000     0.989000    11.000000
#
#           Loudness         Mode  Speechiness  Acousticness  Instrumentalness  \
# count  1943.000000  1943.000000  1943.000000   1943.000000       1943.000000
# mean     -6.503443     0.600103     0.092241      0.208861          0.017590
# std       2.890236     0.490003     0.087744      0.237852          0.092935
# min     -40.449000     0.000000     0.000000      0.000008          0.000000
# 25%      -7.684000     0.000000     0.037800      0.027750          0.000000
# 50%      -5.948000     1.000000     0.054900      0.112000          0.000000
# 75%      -4.668500     1.000000     0.107000      0.310000          0.000102
# max      -0.514000     1.000000     0.592000      0.989000          1.000000
#
#           Liveness      Valence        Tempo       Streams
# count  1943.000000  1943.000000  1943.000000  1.943000e+03
# mean      0.171083     0.505500   120.882904  9.252104e+08
# std       0.130659     0.230059    28.456056  4.472088e+08
# min       0.021500     0.000000     0.000000  1.250320e+07
# 25%       0.091300     0.329500    99.005500  6.119805e+08
# 50%       0.118000     0.502000   119.972000  7.685998e+08
# 75%       0.205000     0.685000   138.917000  1.080691e+09
# max       0.914000     0.980000   205.846000  4.114815e+09

# %%
print((dataset == 0).sum())
# Out:
# Track Name            0
# Artist Name           0
# Album Name            0
# Release Date          0
# Popularity           54
# Duration (ms)         0
# Danceability          3
# Energy                0
# Key                 224
# Loudness              0
# Mode                777
# Speechiness           3
# Acousticness          0
# Instrumentalness    976
# Liveness              0
# Valence               3
# Tempo                 3
# Streams               0
# dtype: int64

# %%
#Boxplot - verificação de outliers
plt.figure(figsize=(6,3))
sns.boxplot(x= dataset['Streams'])
plt.title('Streams', fontsize=14)
plt.show()

# %%
#Matriz de correlação
matriz_correlacao = dataset.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(matriz_correlacao, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
#Histogramas
dataset.hist(figsize=(12, 9))
plt.show()

# %%
#Ano de lançamento
plt.figure(figsize=(10, 6))
plt.hist(dataset['Release Date'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição dos anos de lançamento')
plt.xlabel('Release Date')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### 4. Pré processamento dos dados

# %%
#One hot encoding
dataset = pd.get_dummies(dataset, columns=['Key'], prefix='Key', drop_first=False, dtype='int64')
dataset = pd.get_dummies(dataset, columns=['Mode'], prefix='Mode', drop_first=False, dtype='int64')

# %%
#Deletando colunas de texto, que não serão necessárias para a análise
colunasremovidas = ['Track Name', 'Artist Name', 'Album Name', 'Instrumentalness']
dataset = dataset.drop(colunasremovidas, axis=1)

# %%
dataset['Release Date'] = dataset['Release Date'].dt.year
dataset['Release Date'] = dataset['Release Date'].astype('int64')

# %%
dataset.columns
# Out:
# Index(['Release Date', 'Popularity', 'Duration (ms)', 'Danceability', 'Energy',
#        'Loudness', 'Speechiness', 'Acousticness', 'Liveness', 'Valence',
#        'Tempo', 'Streams', 'Key_0', 'Key_1', 'Key_2', 'Key_3', 'Key_4',
#        'Key_5', 'Key_6', 'Key_7', 'Key_8', 'Key_9', 'Key_10', 'Key_11',
#        'Mode_0', 'Mode_1'],
#       dtype='object')

# %%
ordemcolunas = [ 'Release Date',
       'Duration (ms)', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
       'Acousticness', 'Liveness', 'Valence', 'Tempo',
       'Key_0', 'Key_1', 'Key_2', 'Key_3', 'Key_4', 'Key_5', 'Key_6', 'Key_7',
       'Key_8', 'Key_9', 'Key_10', 'Key_11', 'Mode_0', 'Mode_1', 'Popularity', 'Streams']
dataset = dataset[ordemcolunas]

# %%
#Matriz de correlação
matriz_correlacao = dataset.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(matriz_correlacao, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
X = dataset.iloc[:,:-1]
y = dataset.iloc[:, -1]

# %%
X.head()
# Out:
#    Release Date  Duration (ms)  Danceability  Energy  Loudness  Speechiness  \
# 0          2020         200046         0.518   0.727    -5.947       0.0557
# 1          2017         233713         0.825   0.652    -3.183       0.0802
# 2          2019         182173         0.501   0.405    -5.679       0.0319
# 3          2019         157560         0.755   0.522    -4.368       0.0575
# 4          2016         230453         0.679   0.587    -7.015       0.2760
#
#    Acousticness  Liveness  Valence    Tempo  ...  Key_5  Key_6  Key_7  Key_8  \
# 0       0.00153    0.0882    0.342  170.962  ...      0      0      0      0
# 1       0.58100    0.0931    0.931   95.977  ...      0      0      0      0
# 2       0.75100    0.1050    0.446  109.891  ...      0      0      0      0
# 3       0.53300    0.0685    0.925   89.960  ...      0      0      0      0
# 4       0.14100    0.1370    0.486  186.003  ...      0      0      1      0
#
#    Key_9  Key_10  Key_11  Mode_0  Mode_1  Popularity
# 0      0       0       0       0       1          49
# 1      0       0       0       1       0          88
# 2      0       0       0       0       1          50
# 3      0       0       0       0       1          86
# 4      0       0       0       0       1          93
#
# [5 rows x 25 columns]

# %%
y.head()
# Out:
# 0    4114814660
# 1    3810796529
# 2    3261687586
# 3    3201899849
# 4    3096941898
# Name: Streams, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

# %%
#Random Forest com os melhores hiperparametros - utilizando o Grid Search (Pode demorar de 1 a 2 minutos para rodar)
param_grid = {'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto']}

rf_model = RandomForestRegressor()
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

#Melhores hiperparâmetros encontrados
best_params = grid_search.best_params_
best_rf_model = RandomForestRegressor(**best_params)
best_rf_model.fit(X_train, y_train)

#Previsão
y_pred = best_rf_model.predict(X_test)

#Scores
print("R2 Score:", r2_score(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.20177365816136994
# Mean Squared Error: 1.3145396823172755e+17

# %%
# Actual vs. Predicted Streams
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6, edgecolor=None)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', lw=2)
plt.xlabel('Actual Streams')
plt.ylabel('Predicted Streams')
plt.title('Residuais vs. Streams Previstas')
plt.show()

# %%
# Plot the residuals against predicted streams to assess model accuracy.
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_pred, y=residuals, alpha=0.6, edgecolor=None)
plt.axhline(0, color='red', linestyle='--', lw=2)
plt.xlabel('Streams Previstas')
plt.ylabel('Residuais')
plt.title('Residuais vs. Streams Previstas')
plt.show()
